# %% [markdown]
# # Minimizing Cost in Linear Regression with TF

# %% [markdown]
# https://github.com/deeplearningzerotoall/TensorFlow/blob/master/tf_2.x/lab-03-1-Linear-Regression-and-Minimizing-Cost-eager.ipynb
# https://github.com/hunkim/DeepLearningZeroToAll/blob/master/tf2/tf2-03-1-minimizing_cost_show_graph.py

# %% [markdown]
# ## Read in Libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Recap (using tf.keras for linear regression)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=1))

sgd = tf.keras.optimizers.SGD(lr=0.1)
tf.model.compile(loss='mse', optimizer=sgd)

tf.model.summary()

# fit() trains the model and returns history of train
history = tf.model.fit(x_train, y_train, epochs=100)

y_predict = tf.model.predict(np.array([5, 4]))
print(y_predict)

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9902
# Epoch 2/100
# 1/1 [==============================] - 0s 989us/step - loss: 0.9526
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4833
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2693
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1701
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1227
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0986
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0853
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0769
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0708
# Epoch 11/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0660
# Epoch 12/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0618
# Epoch 13/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0580
# Epoch 14/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0545
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0513
# Epoch 16/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0482
# Epoch 17/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0454
# Epoch 18/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0427
# Epoch 19/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0402
# Epoch 20/100
# 1/1 [==============================] - 0s 993us/step - loss: 0.0378
# Epoch 21/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0356
# Epoch 22/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 23/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0315
# Epoch 24/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0296
# Epoch 25/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0279
# Epoch 26/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0262
# Epoch 27/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0247
# Epoch 28/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0232
# Epoch 29/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0219
# Epoch 30/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0206
# Epoch 31/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0194
# Epoch 32/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0182
# Epoch 33/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0172
# Epoch 34/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0161
# Epoch 35/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 36/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 37/100
# 1/1 [==============================] - 0s 981us/step - loss: 0.0134
# Epoch 38/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 39/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0119
# Epoch 40/100
# 1/1 [==============================] - 0s 969us/step - loss: 0.0112
# Epoch 41/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0105
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 44/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 45/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 46/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0078
# Epoch 47/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0073
# Epoch 48/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0069
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 50/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0061
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0057
# Epoch 52/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0054
# Epoch 53/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0051
# Epoch 54/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0048
# Epoch 55/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0045
# Epoch 56/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0042
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 58/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0038
# Epoch 59/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 61/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 63/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 64/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 66/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 67/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 68/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 74/100
# 1/1 [==============================] - 0s 921us/step - loss: 0.0014
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 76/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 77/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 78/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 80/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.8489e-04
# Epoch 81/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.2680e-04
# Epoch 82/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.7214e-04
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.2070e-04
# Epoch 84/100
# 1/1 [==============================] - 0s 963us/step - loss: 7.7229e-04
# Epoch 85/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.2674e-04
# Epoch 86/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.8387e-04
# Epoch 87/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.4354e-04
# Epoch 88/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.0558e-04
# Epoch 89/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6986e-04
# Epoch 90/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3625e-04
# Epoch 91/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0462e-04
# Epoch 92/100
# 1/1 [==============================] - 0s 957us/step - loss: 4.7486e-04
# Epoch 93/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4685e-04
# Epoch 94/100
# 1/1 [==============================] - 0s 998us/step - loss: 4.2049e-04
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9569e-04
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7236e-04
# Epoch 97/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5039e-04
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2973e-04
# Epoch 99/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1028e-04
# Epoch 100/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9198e-04
# [[-3.9715834]
#  [-2.9853787]]

# %% [markdown]
# ## Cost functions in pure python

# %%
import numpy as np

X = np.array([1, 2, 3])
Y = np.array([1, 2, 3])

def cost_func(W, X, Y):
    c = 0
    for i in range(len(X)):
        c += (W * X[i] - Y[i]) ** 2
    return c / len(X)

for feed_W in np.linspace(-3, 5, num=15):
    curr_cost = cost_func(feed_W, X, Y)
    print("{:6.3f} | {:10.5f}".format(feed_W, curr_cost))
# Out:
# -3.000 |   74.66667
# -2.429 |   54.85714
# -1.857 |   38.09524
# -1.286 |   24.38095
# -0.714 |   13.71429
# -0.143 |    6.09524
#  0.429 |    1.52381
#  1.000 |    0.00000
#  1.571 |    1.52381
#  2.143 |    6.09524
#  2.714 |   13.71429
#  3.286 |   24.38095
#  3.857 |   38.09524
#  4.429 |   54.85714
#  5.000 |   74.66667

# %% [markdown]
# ## Cost Function in TF

# %%
X = np.array([1, 2, 3])
Y = np.array([1, 2, 3])

def cost_func(W, X, Y):
    hypothesis = X * W
    return tf.reduce_mean(tf.square(hypothesis - Y))

W_values = np.linspace(-3, 5, num=15)
cost_values = []

for feed_W in W_values:
    curr_cost = cost_func(feed_W, X, Y)
    cost_values.append(curr_cost)
    print("{:6.3f} | {:10.5f}".format(feed_W, curr_cost))
# Out:
# -3.000 |   74.66667
# -2.429 |   54.85714
# -1.857 |   38.09524
# -1.286 |   24.38095
# -0.714 |   13.71429
# -0.143 |    6.09524
#  0.429 |    1.52381
#  1.000 |    0.00000
#  1.571 |    1.52381
#  2.143 |    6.09524
#  2.714 |   13.71429
#  3.286 |   24.38095
#  3.857 |   38.09524
#  4.429 |   54.85714
#  5.000 |   74.66667

# %%
plt.rcParams["figure.figsize"] = (8,6)
plt.plot(W_values, cost_values, "b")
plt.ylabel('Cost(W)')
plt.xlabel('W')
plt.show()

# %% [markdown]
# ## Gradient Descent Implementation

# %%
tf.random.set_seed(0)  # for reproducibility

# %%
x_data = [1., 2., 3., 4.]
y_data = [1., 3., 5., 7.]

W = tf.Variable(tf.random.normal((1,), -100., 100.))

for step in range(300):
    hypothesis = W * X
    cost = tf.reduce_mean(tf.square(hypothesis - Y))

    alpha = 0.01
    gradient = tf.reduce_mean(tf.multiply(tf.multiply(W, X) - Y, X))
    descent = W - tf.multiply(alpha, gradient)
    W.assign(descent)
    
    if step % 10 == 0:
        print('{:5} | {:10.4f} | {:10.6f}'.format(
            step, cost.numpy(), W.numpy()[0]))
# Out:
#     0 | 11716.3086 |  48.767971
#    10 |  4504.9126 |  30.619968
#    20 |  1732.1364 |  19.366755
#    30 |   666.0052 |  12.388859
#    40 |   256.0785 |   8.062004
#    50 |    98.4620 |   5.379007
#    60 |    37.8586 |   3.715335
#    70 |    14.5566 |   2.683725
#    80 |     5.5970 |   2.044044
#    90 |     2.1520 |   1.647391
#   100 |     0.8275 |   1.401434
#   110 |     0.3182 |   1.248922
#   120 |     0.1223 |   1.154351
#   130 |     0.0470 |   1.095710
#   140 |     0.0181 |   1.059348
#   150 |     0.0070 |   1.036801
#   160 |     0.0027 |   1.022819
#   170 |     0.0010 |   1.014150
#   180 |     0.0004 |   1.008774
#   190 |     0.0002 |   1.005441
#   200 |     0.0001 |   1.003374
#   210 |     0.0000 |   1.002092
#   220 |     0.0000 |   1.001297
#   230 |     0.0000 |   1.000804
#   240 |     0.0000 |   1.000499
#   250 |     0.0000 |   1.000309
#   260 |     0.0000 |   1.000192
#   270 |     0.0000 |   1.000119
#   280 |     0.0000 |   1.000074
#   290 |     0.0000 |   1.000046

# %%
print(5.0 * W)
print(2.5 * W)
# Out:
# tf.Tensor([5.0001483], shape=(1,), dtype=float32)
# tf.Tensor([2.5000741], shape=(1,), dtype=float32)

# %%
x_data = [1., 2., 3., 4.]
y_data = [1., 3., 5., 7.]

W = tf.Variable([5.0])

for step in range(300):
    hypothesis = W * X
    cost = tf.reduce_mean(tf.square(hypothesis - Y))

    alpha = 0.01
    gradient = tf.reduce_mean(tf.multiply(tf.multiply(W, X) - Y, X))
    descent = W - tf.multiply(alpha, gradient)
    W.assign(descent)
    
    if step % 10 == 0:
        print('{:5} | {:10.4f} | {:10.6f}'.format(
            step, cost.numpy(), W.numpy()[0]))
# Out:
#     0 |    74.6667 |   4.813334
#    10 |    28.7093 |   3.364572
#    20 |    11.0387 |   2.466224
#    30 |     4.2444 |   1.909177
#    40 |     1.6320 |   1.563762
#    50 |     0.6275 |   1.349578
#    60 |     0.2413 |   1.216766
#    70 |     0.0928 |   1.134412
#    80 |     0.0357 |   1.083346
#    90 |     0.0137 |   1.051681
#   100 |     0.0053 |   1.032047
#   110 |     0.0020 |   1.019871
#   120 |     0.0008 |   1.012322
#   130 |     0.0003 |   1.007641
#   140 |     0.0001 |   1.004738
#   150 |     0.0000 |   1.002938
#   160 |     0.0000 |   1.001822
#   170 |     0.0000 |   1.001130
#   180 |     0.0000 |   1.000700
#   190 |     0.0000 |   1.000434
#   200 |     0.0000 |   1.000269
#   210 |     0.0000 |   1.000167
#   220 |     0.0000 |   1.000103
#   230 |     0.0000 |   1.000064
#   240 |     0.0000 |   1.000040
#   250 |     0.0000 |   1.000025
#   260 |     0.0000 |   1.000015
#   270 |     0.0000 |   1.000009
#   280 |     0.0000 |   1.000006
#   290 |     0.0000 |   1.000004
